# %%
import numpy as np
import pandas as pd
column_name = "Comptes", "Duree_credit", "Historique_credit", "Objet_credit", "Montant_credit", "Epargne", "Anciennete_emploi", "taux_effort", "Situation_familiale", "Garanties", "Anciennete_domicile", "Biens", "Age", "Autres_credits", "Statut_domicile", "Nb_credits", "Type_emploi", "Nb_pers_charge", "Telephone", "Etranger", "Cible"
df = pd.read_csv('credit (1).txt', delim_whitespace=True, names=column_name)
df
# Out:
#     Comptes  Duree_credit Historique_credit Objet_credit  Montant_credit  \
# 0       A11             6               A34          A43            1169
# 1       A12            48               A32          A43            5951
# 2       A14            12               A34          A46            2096
# 3       A11            42               A32          A42            7882
# 4       A11            24               A33          A40            4870
# 5       A14            36               A32          A46            9055
# 6       A14            24               A32          A42            2835
# 7       A12            36               A32          A41            6948
# 8       A14            12               A32          A43            3059
# 9       A12            30               A34          A40            5234
# 10      A12            12               A32          A40            1295
# 11      A11            48               A32          A49            4308
# ...

# %%
df.describe()
# Out:
#        Duree_credit  Montant_credit  taux_effort  Anciennete_domicile  \
# count   1000.000000     1000.000000  1000.000000          1000.000000
# mean      20.903000     3271.258000     2.973000             2.845000
# std       12.058814     2822.736876     1.118715             1.103718
# min        4.000000      250.000000     1.000000             1.000000
# 25%       12.000000     1365.500000     2.000000             2.000000
# 50%       18.000000     2319.500000     3.000000             3.000000
# 75%       24.000000     3972.250000     4.000000             4.000000
# max       72.000000    18424.000000     4.000000             4.000000
#
#                Age   Nb_credits  Nb_pers_charge        Cible
# count  1000.000000  1000.000000     1000.000000  1000.000000
# mean     35.546000     1.407000        1.155000     1.300000
# std      11.375469     0.577654        0.362086     0.458487
# min      19.000000     1.000000        1.000000     1.000000
# ...

# %% [markdown]
# # HOW TO CREATE AN INSTANCE OF THE CLASSIFIER

# %%
from sklearn import linear_model
logClassifier = linear_model.LogisticRegression(C=1, random_state=111)

# %% [markdown]
# # HOW TO RUN THE TRAINING DATA

# %%
'credit (1).txt'

# %%
from sklearn import cross_validation
credit = read_csv()'credit (1).txt'
X_train, X_test, y_train, y_test = cross_validation.train_test_split(credit.data, credit.target, test_size=0.10, random_state=111)
logClassifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5912e591bcd7> in <module>()
#       1 from sklearn import cross_validation
#       2 credit = 'credit (1).txt'
# ----> 3 X_train, X_test, y_train, y_test = cross_validation.train_test_split(credit.data, credit.target, test_size=0.10, random_state=111)
#       4 logClassifier.fit(X_train, y_train)
#
# AttributeError: 'str' object has no attribute 'data'

# %%
print(credit (1).txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-94ca7b9d4954> in <module>()
# ----> 1 print(credit (1).txt)
#
# TypeError: 'str' object is not callable
