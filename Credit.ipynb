# %%
"""
import numpy as np
import pandas as pd
column_name = "Comptes", "Duree_credit", "Historique_credit", "Objet_credit", "Montant_credit", "Epargne", "Anciennete_emploi", "taux_effort", "Situation_familiale", "Garanties", "Anciennete_domicile", "Biens", "Age", "Autres_credits", "Statut_domicile", "Nb_credits", "Type_emploi", "Nb_pers_charge", "Telephone", "Etranger", "Cible"
df = pd.read_csv('credit (1).txt', delim_whitespace=True, names=column_name)
df
"""
# Out:
# '\nimport numpy as np\nimport pandas as pd\ncolumn_name = "Comptes", "Duree_credit", "Historique_credit", "Objet_credit", "Montant_credit", "Epargne", "Anciennete_emploi", "taux_effort", "Situation_familiale", "Garanties", "Anciennete_domicile", "Biens", "Age", "Autres_credits", "Statut_domicile", "Nb_credits", "Type_emploi", "Nb_pers_charge", "Telephone", "Etranger", "Cible"\ndf = pd.read_csv(\'credit (1).txt\', delim_whitespace=True, names=column_name)\ndf\n'

# %%
"""
df.describe()
"""
# Out:
# '\ndf.describe()\n'

# %% [markdown]
# # HOW TO CREATE AN INSTANCE OF THE CLASSIFIER NA

# %%
from sklearn import linear_model
logClassifier = linear_model.LogisticRegression(C=1, random_state=111)

# %% [markdown]
# # HOW TO RUN THE TRAINING DATA NA

# %%
'credit (1).txt'
# Out:
# 'credit (1).txt'

# %%
"""
from sklearn import cross_validation
credit = read_csv()'credit (1).txt'
X_train, X_test, y_train, y_test = cross_validation.train_test_split(credit.data, credit.target, test_size=0.10, random_state=111)
logClassifier.fit(X_train, y_train)
"""
# Out:
# "\nfrom sklearn import cross_validation\ncredit = read_csv()'credit (1).txt'\nX_train, X_test, y_train, y_test = cross_validation.train_test_split(credit.data, credit.target, test_size=0.10, random_state=111)\nlogClassifier.fit(X_train, y_train)\n"

# %%
"""
print(credit (1).txt)
"""
# Out:
# '\nprint(credit (1).txt)\n'

# %% [markdown]
# ## Libraries:

# %%
#Load the libraries
import pandas as pd # "To work with dataset
import numpy as np # Math library
import seaborn as sns # Graph library that uses matplot in background
import matplotlib.pyplot as plt # to plot some parameters in seaborn

# Importing the data
df_credit = pd.read_csv('./data/credit.txt',index_col=0)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Abdoulaye\\Desktop\\Cours\\Datascience\\Credit'

# %% [markdown]
# ## First Look at the data:

# %%
# Searching for missing data, type of data and know its shape
print(df_credit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, A12 48 A32 A43 5951 A61 A73 2 A92 A101 2 A121 22 A143 A152 1 A173 1 A191 A201 2 to A12 45 A34 A41 4576 A62 A71 3 A93 A101 4 A123 27 A143 A152 1 A173 1 A191 A201 1
# Empty DataFrameNone

# %%
# Looking for unique values
print(df_credit.nunique())
print("_______________")
# Looking at the data
print(df_credit.head())
# Out:
# Series([], dtype: float64)
# _______________
# Empty DataFrame
# Columns: []
# Index: [A12 48 A32 A43 5951 A61 A73 2 A92 A101 2 A121 22 A143 A152 1 A173 1 A191 A201 2, A14 12 A34 A46 2096 A61 A74 2 A93 A101 3 A121 49 A143 A152 1 A172 2 A191 A201 1, A11 42 A32 A42 7882 A61 A74 2 A93 A103 4 A122 45 A143 A153 1 A173 2 A191 A201 1, A11 24 A33 A40 4870 A61 A73 3 A93 A101 4 A124 53 A143 A153 2 A173 2 A191 A201 2, A14 36 A32 A46 9055 A65 A73 2 A93 A101 4 A124 35 A143 A153 1 A172 2 A192 A201 1]

# %%
# Looking for unique values
print(df_credit.nunique())
print("_______________")
# Looking at the data
column_name = "Comptes", "Duree_credit", "Historique_credit", "Objet_credit", "Montant_credit", "Epargne", "Anciennete_emploi", "taux_effort", "Situation_familiale", "Garanties", "Anciennete_domicile", "Biens", "Age", "Autres_credits", "Statut_domicile", "Nb_credits", "Type_emploi", "Nb_pers_charge", "Telephone", "Etranger", "Cible"
df_credit = pd.read_csv('./data/credit.txt', delim_whitespace=True, names=column_name)
df_credit.head()
# Out:
# Series([], dtype: float64)
# _______________
#   Comptes  Duree_credit Historique_credit Objet_credit  Montant_credit  \
# 0     A11             6               A34          A43            1169
# 1     A12            48               A32          A43            5951
# 2     A14            12               A34          A46            2096
# 3     A11            42               A32          A42            7882
# 4     A11            24               A33          A40            4870
#
#   Epargne Anciennete_emploi  taux_effort Situation_familiale Garanties  ...   \
# 0     A65               A75            4                 A93      A101  ...
# 1     A61               A73            2                 A92      A101  ...
# 2     A61               A74            2                 A93      A101  ...
# 3     A61               A74            2                 A93      A103  ...
# 4     A61               A73            3                 A93      A101  ...
#
# ...

# %%
print(df_credit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# Comptes                1000 non-null object
# Duree_credit           1000 non-null int64
# Historique_credit      1000 non-null object
# Objet_credit           1000 non-null object
# Montant_credit         1000 non-null int64
# Epargne                1000 non-null object
# Anciennete_emploi      1000 non-null object
# taux_effort            1000 non-null int64
# Situation_familiale    1000 non-null object
# Garanties              1000 non-null object
# Anciennete_domicile    1000 non-null int64
# Biens                  1000 non-null object
# Age                    1000 non-null category
# Autres_credits         1000 non-null object
# Statut_domicile        1000 non-null object
# Nb_credits             1000 non-null int64
# Type_emploi            1000 non-null object
# Nb_pers_charge         1000 non-null int64
# Telephone              1000 non-null object
# ...

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
from collections import Counter

trace0 = go.Bar(
            x = df_credit[df_credit["Cible"]== 2]["Cible"].value_counts().index.values,
            y = df_credit[df_credit["Cible"]== 2]["Cible"].value_counts().values,
            name='Good credit'
    )

trace1 = go.Bar(
            x = df_credit[df_credit["Cible"]== 1]["Cible"].value_counts().index.values,
            y = df_credit[df_credit["Cible"]== 1]["Cible"].value_counts().values,
            name='Bad credit'
    )

data = [trace0, trace1]

layout = go.Layout(
    
)

layout = go.Layout(
    yaxis=dict(
        title='Count'
    ),
    xaxis=dict(
        title='Risk Variable'
    ),
    title='Target variable distribution'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='grouped-bar')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="908e6b15-5058-4998-b38c-12851be7c4a5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '908e6b15-5058-4998-b38c-12851be7c4a5',
#             [{"name": "Good credit", "x": [2.0], "y": [300.0], "type": "bar", "uid": "5d02705c-85cf-11e8-a575-985fd3416bc2"}, {"name": "Bad credit", "x": [1.0], "y": [700.0], "type": "bar", "uid": "5d03627a-85cf-11e8-9a31-985fd3416bc2"}],
#             {"title": "Target variable distribution", "xaxis": {"title": "Risk Variable"}, "yaxis": {"title": "Count"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
# ...

# %%
type(df_credit["Cible"][0])
# Out:
# numpy.int64

# %% [markdown]
# Risk: Cible -
# good: 2
# bad: 1

# %%
df_good = df_credit.loc[df_credit["Cible"] == 2]['Age'].values.tolist()
df_bad = df_credit.loc[df_credit["Cible"] == 1]['Age'].values.tolist()
df_age = df_credit['Age'].values.tolist()

# First plot
trace0 = go.Histogram(
    x=df_good,
    histnorm='probability',
    name="Good Credit"
)
# Second plot
trace1 = go.Histogram(
    x=df_bad,
    histnorm='probability',
    name="Bad Credit"
)
# Third plot
trace2 = go.Histogram(
    x=df_age,
    histnorm='probability',
    name="Overall Age"
)

# Creating the grid
fig = tls.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
                          subplot_titles=('Good','Bad', 'General Distribution'))

# setting the figs
fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)
fig.append_trace(trace2, 2, 1)

fig['layout'].update(showlegend=True, title='Age Distribution', bargap=0.05)
py.iplot(fig, filename='custom-sized-subplot-with-subplot-titles')
# Out:
# C:\Users\Abdoulaye\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3           -      ]
# <div id="75d985bd-a0fd-456c-b330-5945de8cac88" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '75d985bd-a0fd-456c-b330-5945de8cac88',
# ...

# %% [markdown]
# ## Creating an categorical variable to handle with the Age variable

# %% [markdown]
# ### Let's look at the Montant_credit column

# %%
interval = (18, 25, 35, 60, 120)

cats = ['millenials', 'Young', 'Adult', 'Senior']
df_credit['Age'] = pd.cut(df_credit.Age, interval, labels=cats)


df_good = df_credit[df_credit["Cible"] == 2]
df_bad = df_credit[df_credit["Cible"] == 1]

# %%
trace0 = go.Box(
    y=df_good["Montant_credit"],
    x=df_good["Age"],
    name='Good credit',
    marker=dict(
        color='#3D9970'
    )
)

trace1 = go.Box(
    y=df_bad['Montant_credit'],
    x=df_bad['Age'],
    name='Bad credit',
    marker=dict(
        color='#FF4136'
    )
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Credit Amount (Euros)',
        zeroline=False
    ),
    xaxis=dict(
        title='Age Categorical'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')
# Out:
# <div id="5b3f69ae-e24a-4169-932e-ac2cdec3a61d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5b3f69ae-e24a-4169-932e-ac2cdec3a61d',
# ...

# %% [markdown]
# ## Look the distribuition of Housing own and rent by Risk

# %%
# First plot
trace0 = go.Bar(
    x = df_credit[df_credit["Cible"]== 2]["Statut_domicile"].value_counts().index.values,
    y = df_credit[df_credit["Cible"]== 2]["Statut_domicile"].value_counts().values,
    name='Good credit'
)

# Second plot
trace1 = go.Bar(
    x = df_credit[df_credit["Cible"]== 1]["Statut_domicile"].value_counts().index.values,
    y = df_credit[df_credit["Cible"]== 1]["Statut_domicile"].value_counts().values,
    name="Bad Credit"
)

data = [trace0, trace1]

layout = go.Layout(
    title='Housing Distribution'
)


fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='Housing-Grouped')
# Out:
# <div id="5d384a63-2637-4cb7-9828-427e39e33af5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5d384a63-2637-4cb7-9828-427e39e33af5',
#             [{"name": "Good credit", "x": ["A152", "A151", "A153"], "y": [186.0, 70.0, 44.0], "type": "bar", "uid": "dd25c7f4-85d3-11e8-90f4-985fd3416bc2"}, {"name": "Bad Credit", "x": ["A152", "A151", "A153"], "y": [527.0, 109.0, 64.0], "type": "bar", "uid": "dd25ef0a-85d3-11e8-9e6d-985fd3416bc2"}],
#             {"title": "Housing Distribution"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('5d384a63-2637-4cb7-9828-427e39e33af5',{});}).then(function(){Plotly.animate('5d384a63-2637-4cb7-9828-427e39e33af5');})
#         });</script>
